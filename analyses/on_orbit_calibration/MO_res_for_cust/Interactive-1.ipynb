# %% [markdown]
# Connected to tudat-space (Python 3.10.9)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os 
import datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import importlib
import os, sys
sys.path.insert(1, os.getcwd()[:os.getcwd().index('astropynaric')+13])
## MVP imports
import basic_tools.vector_operations as vec_calc
import astronomy_tools.constants as const
import astronomy_tools.astro_targets as where_sun
import plotting_tools.basic_plotting as bplt
import basic_tools.time_conversion as t_conv
import basic_tools.in_out as out
import attitude_tools.conversions as conv
import analyses.on_orbit_calibration.MO_res_for_cust.resolve_Qmo as Q_mo_fix
importlib.reload(conv)

# read log
def get_cmd_from_log(logname, rownr = None, arr = None):
    if arr is None:
        arr = np.genfromtxt(logname, delimiter = ';', skip_header=3)

    ae_cmd_all = arr[:,[3,4]]
    ae_tracked = arr[:,[5,6]]
    if rownr is None:
        row_chosen = int(arr.shape[0]/1.3)
    else:
        row_chosen = rownr
    ae_tracked_chosen = np.rad2deg(1e-6*ae_tracked[row_chosen,:])
    ae_cmd_chosen = ae_cmd_all[row_chosen,:]

    return ae_tracked_chosen, ae_cmd_chosen 


if __name__ == '__main__':
    import scipy as sp

    path = r'analyses/on_orbit_calibration/MO_res_for_cust'
    fname_log1 = 'Moon_29-01-2024_230229_PM.csv'

    arr = np.genfromtxt(f'{path}/{fname_log1}', delimiter=';', skip_header=4)

    ii_start_man = np.where(arr[:,-2] == 1)[0][0]
    
    t_vec_all_from0 = arr[:,1] + arr[:,2]*1e-3 - arr[0,1]
    t_vec_used = t_vec_all_from0[:ii_start_man]
    ae_moon = arr[:ii_start_man,[3,4]]

    tstart_man = t_vec_all_from0[ii_start_man:,1]
    t_vec_man = [tstart_man[0] + ii*0.05 for ii, t in enumerate(tstart_man)]


    az_moon_exrapoator = sp.interpolate.interp1d(ae_moon[:,0], t_vec_used, fill_value = 'extrapolate', kind = 'linear')
    el_moon_exrapoator = sp.interpolate.interp1d(ae_moon[:,1], t_vec_used, fill_value = 'extrapolate', kind = 'linear')

    ae_at_tman = [
    az_moon_exrapoator(tstart_man[0]),
    el_moon_exrapoator(tstart_man[0])
    ]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File c:\Users\KPaliusis\Documents\Github_Repos\astropynaric\analyses\on_orbit_calibration\MO_res_for_cust\get_moon_deltas_for_square_raster.py:54
#      51 t_vec_used = t_vec_all_from0[:ii_start_man]
#      52 ae_moon = arr[:ii_start_man,[3,4]]
# ---> 54 tstart_man = t_vec_all_from0[ii_start_man:,1]
#      55 t_vec_man = [tstart_man[0] + ii*0.05 for ii, t in enumerate(tstart_man)]
#      58 az_moon_exrapoator = sp.interpolate.interp1d(ae_moon[:,0], t_vec_used, fill_value = 'extrapolate', kind = 'linear')
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os 
import datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import importlib
import os, sys
sys.path.insert(1, os.getcwd()[:os.getcwd().index('astropynaric')+13])
## MVP imports
import basic_tools.vector_operations as vec_calc
import astronomy_tools.constants as const
import astronomy_tools.astro_targets as where_sun
import plotting_tools.basic_plotting as bplt
import basic_tools.time_conversion as t_conv
import basic_tools.in_out as out
import attitude_tools.conversions as conv
import analyses.on_orbit_calibration.MO_res_for_cust.resolve_Qmo as Q_mo_fix
importlib.reload(conv)

# read log
def get_cmd_from_log(logname, rownr = None, arr = None):
    if arr is None:
        arr = np.genfromtxt(logname, delimiter = ';', skip_header=3)

    ae_cmd_all = arr[:,[3,4]]
    ae_tracked = arr[:,[5,6]]
    if rownr is None:
        row_chosen = int(arr.shape[0]/1.3)
    else:
        row_chosen = rownr
    ae_tracked_chosen = np.rad2deg(1e-6*ae_tracked[row_chosen,:])
    ae_cmd_chosen = ae_cmd_all[row_chosen,:]

    return ae_tracked_chosen, ae_cmd_chosen 


if __name__ == '__main__':
    import scipy as sp

    path = r'analyses/on_orbit_calibration/MO_res_for_cust'
    fname_log1 = 'Moon_29-01-2024_230229_PM.csv'

    arr = np.genfromtxt(f'{path}/{fname_log1}', delimiter=';', skip_header=4)

    ii_start_man = np.where(arr[:,-2] == 1)[0][0]
    
    t_vec_all_from0 = arr[:,1] + arr[:,2]*1e-3 - arr[0,1]
    t_vec_used = t_vec_all_from0[:ii_start_man]
    ae_moon = arr[:ii_start_man,[3,4]]

    tstart_man = t_vec_all_from0[ii_start_man]
    t_vec_man = [tstart_man[0] + ii*0.05 for ii, t in enumerate(tstart_man)]


    az_moon_exrapoator = sp.interpolate.interp1d(ae_moon[:,0], t_vec_used, fill_value = 'extrapolate', kind = 'linear')
    el_moon_exrapoator = sp.interpolate.interp1d(ae_moon[:,1], t_vec_used, fill_value = 'extrapolate', kind = 'linear')

    ae_at_tman = [
    az_moon_exrapoator(tstart_man[0]),
    el_moon_exrapoator(tstart_man[0])
    ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\KPaliusis\Documents\Github_Repos\astropynaric\analyses\on_orbit_calibration\MO_res_for_cust\get_moon_deltas_for_square_raster.py:55
#      52 ae_moon = arr[:ii_start_man,[3,4]]
#      54 tstart_man = t_vec_all_from0[ii_start_man]
# ---> 55 t_vec_man = [tstart_man[0] + ii*0.05 for ii, t in enumerate(tstart_man)]
#      58 az_moon_exrapoator = sp.interpolate.interp1d(ae_moon[:,0], t_vec_used, fill_value = 'extrapolate', kind = 'linear')
#      59 el_moon_exrapoator = sp.interpolate.interp1d(ae_moon[:,1], t_vec_used, fill_value = 'extrapolate', kind = 'linear')
#
# TypeError: 'numpy.float64' object is not iterable

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os 
import datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import importlib
import os, sys
sys.path.insert(1, os.getcwd()[:os.getcwd().index('astropynaric')+13])
## MVP imports
import basic_tools.vector_operations as vec_calc
import astronomy_tools.constants as const
import astronomy_tools.astro_targets as where_sun
import plotting_tools.basic_plotting as bplt
import basic_tools.time_conversion as t_conv
import basic_tools.in_out as out
import attitude_tools.conversions as conv
import analyses.on_orbit_calibration.MO_res_for_cust.resolve_Qmo as Q_mo_fix
importlib.reload(conv)

# read log
def get_cmd_from_log(logname, rownr = None, arr = None):
    if arr is None:
        arr = np.genfromtxt(logname, delimiter = ';', skip_header=3)

    ae_cmd_all = arr[:,[3,4]]
    ae_tracked = arr[:,[5,6]]
    if rownr is None:
        row_chosen = int(arr.shape[0]/1.3)
    else:
        row_chosen = rownr
    ae_tracked_chosen = np.rad2deg(1e-6*ae_tracked[row_chosen,:])
    ae_cmd_chosen = ae_cmd_all[row_chosen,:]

    return ae_tracked_chosen, ae_cmd_chosen 


if __name__ == '__main__':
    import scipy as sp

    path = r'analyses/on_orbit_calibration/MO_res_for_cust'
    fname_log1 = 'Moon_29-01-2024_230229_PM.csv'

    arr = np.genfromtxt(f'{path}/{fname_log1}', delimiter=';', skip_header=4)

    ii_start_man = np.where(arr[:,-2] == 1)[0][0]
    
    t_vec_all_from0 = arr[:,1] + arr[:,2]*1e-3 - arr[0,1]
    t_vec_used = t_vec_all_from0[:ii_start_man]
    ae_moon = arr[:ii_start_man,[3,4]]

    tstart_man = t_vec_all_from0[ii_start_man:]
    t_vec_man = [tstart_man[0] + ii*0.05 for ii, t in enumerate(tstart_man)]
    tstart_man = tstart_man[0]

    az_moon_exrapoator = sp.interpolate.interp1d(ae_moon[:,0], t_vec_used, fill_value = 'extrapolate', kind = 'linear')
    el_moon_exrapoator = sp.interpolate.interp1d(ae_moon[:,1], t_vec_used, fill_value = 'extrapolate', kind = 'linear')

    ae_at_tman = [
    az_moon_exrapoator(tstart_man[0]),
    el_moon_exrapoator(tstart_man[0])
    ]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File c:\Users\KPaliusis\Documents\Github_Repos\astropynaric\analyses\on_orbit_calibration\MO_res_for_cust\get_moon_deltas_for_square_raster.py:62
#      58 az_moon_exrapoator = sp.interpolate.interp1d(ae_moon[:,0], t_vec_used, fill_value = 'extrapolate', kind = 'linear')
#      59 el_moon_exrapoator = sp.interpolate.interp1d(ae_moon[:,1], t_vec_used, fill_value = 'extrapolate', kind = 'linear')
#      61 ae_at_tman = [
# ---> 62 az_moon_exrapoator(tstart_man[0]),
#      63 el_moon_exrapoator(tstart_man[0])
#      64 ]
#
# IndexError: invalid index to scalar variable.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os 
import datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import importlib
import os, sys
sys.path.insert(1, os.getcwd()[:os.getcwd().index('astropynaric')+13])
## MVP imports
import basic_tools.vector_operations as vec_calc
import astronomy_tools.constants as const
import astronomy_tools.astro_targets as where_sun
import plotting_tools.basic_plotting as bplt
import basic_tools.time_conversion as t_conv
import basic_tools.in_out as out
import attitude_tools.conversions as conv
import analyses.on_orbit_calibration.MO_res_for_cust.resolve_Qmo as Q_mo_fix
importlib.reload(conv)

# read log
def get_cmd_from_log(logname, rownr = None, arr = None):
    if arr is None:
        arr = np.genfromtxt(logname, delimiter = ';', skip_header=3)

    ae_cmd_all = arr[:,[3,4]]
    ae_tracked = arr[:,[5,6]]
    if rownr is None:
        row_chosen = int(arr.shape[0]/1.3)
    else:
        row_chosen = rownr
    ae_tracked_chosen = np.rad2deg(1e-6*ae_tracked[row_chosen,:])
    ae_cmd_chosen = ae_cmd_all[row_chosen,:]

    return ae_tracked_chosen, ae_cmd_chosen 


if __name__ == '__main__':
    import scipy as sp

    path = r'analyses/on_orbit_calibration/MO_res_for_cust'
    fname_log1 = 'Moon_29-01-2024_230229_PM.csv'

    arr = np.genfromtxt(f'{path}/{fname_log1}', delimiter=';', skip_header=4)

    ii_start_man = np.where(arr[:,-2] == 1)[0][0]
    
    t_vec_all_from0 = arr[:,1] + arr[:,2]*1e-3 - arr[0,1]
    t_vec_used = t_vec_all_from0[:ii_start_man]
    ae_moon = arr[:ii_start_man,[3,4]]

    tstart_man = t_vec_all_from0[ii_start_man:]
    t_vec_man = [tstart_man[0] + ii*0.05 for ii, t in enumerate(tstart_man)]
    tstart_man = tstart_man[0]

    az_moon_exrapoator = sp.interpolate.interp1d(ae_moon[:,0], t_vec_used, fill_value = 'extrapolate', kind = 'linear')
    el_moon_exrapoator = sp.interpolate.interp1d(ae_moon[:,1], t_vec_used, fill_value = 'extrapolate', kind = 'linear')

    ae_at_tman = [
    az_moon_exrapoator(tstart_man),
    el_moon_exrapoator(tstart_man)
    ]
# Out:
# c:\Users\KPaliusis\Anaconda3\envs\tudat-space\lib\site-packages\scipy\interpolate\_interpolate.py:698: RuntimeWarning: invalid value encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]

# %%
az_moon_exrapoator

# %%
ae_at_tman
# Out:
# [array(-1155959.68433597), array(nan)]

# %%
ae_moon[:,1]
# Out:
# array([0.31338546, 0.31338658, 0.31338771, ..., 0.31628517, 0.31628631,
#        0.31628631])

# %%
t_vec_used
# Out:
# array([ 0.74699998,  0.77200007,  0.79699993, ..., 65.55500007,
#        65.57999992, 65.57999992])

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os 
import datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import importlib
import os, sys
sys.path.insert(1, os.getcwd()[:os.getcwd().index('astropynaric')+13])
## MVP imports
import basic_tools.vector_operations as vec_calc
import astronomy_tools.constants as const
import astronomy_tools.astro_targets as where_sun
import plotting_tools.basic_plotting as bplt
import basic_tools.time_conversion as t_conv
import basic_tools.in_out as out
import attitude_tools.conversions as conv
import analyses.on_orbit_calibration.MO_res_for_cust.resolve_Qmo as Q_mo_fix
importlib.reload(conv)

# read log
def get_cmd_from_log(logname, rownr = None, arr = None):
    if arr is None:
        arr = np.genfromtxt(logname, delimiter = ';', skip_header=3)

    ae_cmd_all = arr[:,[3,4]]
    ae_tracked = arr[:,[5,6]]
    if rownr is None:
        row_chosen = int(arr.shape[0]/1.3)
    else:
        row_chosen = rownr
    ae_tracked_chosen = np.rad2deg(1e-6*ae_tracked[row_chosen,:])
    ae_cmd_chosen = ae_cmd_all[row_chosen,:]

    return ae_tracked_chosen, ae_cmd_chosen 


if __name__ == '__main__':
    import scipy as sp

    path = r'analyses/on_orbit_calibration/MO_res_for_cust'
    fname_log1 = 'Moon_29-01-2024_230229_PM.csv'

    arr = np.genfromtxt(f'{path}/{fname_log1}', delimiter=';', skip_header=4)

    ii_start_man = np.where(arr[:,-2] == 1)[0][0]
    
    t_vec_all_from0 = arr[:,1] + arr[:,2]*1e-3 - arr[0,1]
    t_vec_used = t_vec_all_from0[:ii_start_man]
    ae_moon = arr[:ii_start_man,[3,4]]

    tstart_man = t_vec_all_from0[ii_start_man:]
    t_vec_man = [tstart_man[0] + ii*0.05 for ii, t in enumerate(tstart_man)]
    tstart_man = tstart_man[0]

    az_moon_exrapoator = sp.interpolate.interp1d(t_vec_used, ae_moon[:,0],  fill_value = 'extrapolate', kind = 'linear')
    el_moon_exrapoator = sp.interpolate.interp1d(t_vec_used, ae_moon[:,1],  fill_value = 'extrapolate', kind = 'linear')

    ae_at_tman = [
    az_moon_exrapoator(tstart_man),
    el_moon_exrapoator(tstart_man)
    ]

# %%
ae_at_tman
# Out:
# [array(-1.6806296), array(0.31628631)]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os 
import datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import importlib
import os, sys
sys.path.insert(1, os.getcwd()[:os.getcwd().index('astropynaric')+13])
## MVP imports
import basic_tools.vector_operations as vec_calc
import astronomy_tools.constants as const
import astronomy_tools.astro_targets as where_sun
import plotting_tools.basic_plotting as bplt
import basic_tools.time_conversion as t_conv
import basic_tools.in_out as out
import attitude_tools.conversions as conv
import analyses.on_orbit_calibration.MO_res_for_cust.resolve_Qmo as Q_mo_fix
importlib.reload(conv)

# read log
def get_cmd_from_log(logname, rownr = None, arr = None):
    if arr is None:
        arr = np.genfromtxt(logname, delimiter = ';', skip_header=3)

    ae_cmd_all = arr[:,[3,4]]
    ae_tracked = arr[:,[5,6]]
    if rownr is None:
        row_chosen = int(arr.shape[0]/1.3)
    else:
        row_chosen = rownr
    ae_tracked_chosen = np.rad2deg(1e-6*ae_tracked[row_chosen,:])
    ae_cmd_chosen = ae_cmd_all[row_chosen,:]

    return ae_tracked_chosen, ae_cmd_chosen 


if __name__ == '__main__':
    import scipy as sp

    path = r'analyses/on_orbit_calibration/MO_res_for_cust'
    fname_log1 = 'Moon_29-01-2024_230229_PM.csv'

    arr = np.genfromtxt(f'{path}/{fname_log1}', delimiter=';', skip_header=4)

    ii_start_man = np.where(arr[:,-2] == 1)[0][0]
    
    t_vec_all_from0 = arr[:,1] + arr[:,2]*1e-3 - arr[0,1]
    t_vec_used = t_vec_all_from0[:ii_start_man]
    ae_moon = arr[:ii_start_man,[3,4]]

    tstart_man = t_vec_all_from0[ii_start_man:]
    t_vec_man = [tstart_man[0] + ii*0.05 for ii, t in enumerate(tstart_man)]
    tstart_man = tstart_man[0]

    az_moon_exrapoator = sp.interpolate.interp1d(t_vec_used, ae_moon[:,0],  fill_value = 'extrapolate', kind = 'linear')
    el_moon_exrapoator = sp.interpolate.interp1d(t_vec_used, ae_moon[:,1],  fill_value = 'extrapolate', kind = 'linear')

    ae_at_tman = [
    az_moon_exrapoator(tstart_man)[0],
    el_moon_exrapoator(tstart_man)[0]
    ]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File c:\Users\KPaliusis\Documents\Github_Repos\astropynaric\analyses\on_orbit_calibration\MO_res_for_cust\get_moon_deltas_for_square_raster.py:62
#      58 az_moon_exrapoator = sp.interpolate.interp1d(t_vec_used, ae_moon[:,0],  fill_value = 'extrapolate', kind = 'linear')
#      59 el_moon_exrapoator = sp.interpolate.interp1d(t_vec_used, ae_moon[:,1],  fill_value = 'extrapolate', kind = 'linear')
#      61 ae_at_tman = [
# ---> 62 az_moon_exrapoator(tstart_man)[0],
#      63 el_moon_exrapoator(tstart_man)[0]
#      64 ]
#
# IndexError: too many indices for array: array is 0-dimensional, but 1 were indexed

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os 
import datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import importlib
import os, sys
sys.path.insert(1, os.getcwd()[:os.getcwd().index('astropynaric')+13])
## MVP imports
import basic_tools.vector_operations as vec_calc
import astronomy_tools.constants as const
import astronomy_tools.astro_targets as where_sun
import plotting_tools.basic_plotting as bplt
import basic_tools.time_conversion as t_conv
import basic_tools.in_out as out
import attitude_tools.conversions as conv
import analyses.on_orbit_calibration.MO_res_for_cust.resolve_Qmo as Q_mo_fix
importlib.reload(conv)

# read log
def get_cmd_from_log(logname, rownr = None, arr = None):
    if arr is None:
        arr = np.genfromtxt(logname, delimiter = ';', skip_header=3)

    ae_cmd_all = arr[:,[3,4]]
    ae_tracked = arr[:,[5,6]]
    if rownr is None:
        row_chosen = int(arr.shape[0]/1.3)
    else:
        row_chosen = rownr
    ae_tracked_chosen = np.rad2deg(1e-6*ae_tracked[row_chosen,:])
    ae_cmd_chosen = ae_cmd_all[row_chosen,:]

    return ae_tracked_chosen, ae_cmd_chosen 


if __name__ == '__main__':
    import scipy as sp

    path = r'analyses/on_orbit_calibration/MO_res_for_cust'
    fname_log1 = 'Moon_29-01-2024_230229_PM.csv'

    arr = np.genfromtxt(f'{path}/{fname_log1}', delimiter=';', skip_header=4)

    ii_start_man = np.where(arr[:,-2] == 1)[0][0]
    
    t_vec_all_from0 = arr[:,1] + arr[:,2]*1e-3 - arr[0,1]
    t_vec_used = t_vec_all_from0[:ii_start_man]
    ae_moon = arr[:ii_start_man,[3,4]]

    tstart_man = t_vec_all_from0[ii_start_man:]
    t_vec_man = [tstart_man[0] + ii*0.05 for ii, t in enumerate(tstart_man)]
    tstart_man = tstart_man[0]

    az_moon_exrapoator = sp.interpolate.interp1d(t_vec_used, ae_moon[:,0],  fill_value = 'extrapolate', kind = 'linear')
    el_moon_exrapoator = sp.interpolate.interp1d(t_vec_used, ae_moon[:,1],  fill_value = 'extrapolate', kind = 'linear')

    ae_at_tman = [
    az_moon_exrapoator(tstart_man),
    el_moon_exrapoator(tstart_man)
    ]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os 
import datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import importlib
import os, sys
sys.path.insert(1, os.getcwd()[:os.getcwd().index('astropynaric')+13])
## MVP imports
import basic_tools.vector_operations as vec_calc
import astronomy_tools.constants as const
import astronomy_tools.astro_targets as where_sun
import plotting_tools.basic_plotting as bplt
import basic_tools.time_conversion as t_conv
import basic_tools.in_out as out
import attitude_tools.conversions as conv
import analyses.on_orbit_calibration.MO_res_for_cust.resolve_Qmo as Q_mo_fix
importlib.reload(conv)

# read log
def get_cmd_from_log(logname, rownr = None, arr = None):
    if arr is None:
        arr = np.genfromtxt(logname, delimiter = ';', skip_header=3)

    ae_cmd_all = arr[:,[3,4]]
    ae_tracked = arr[:,[5,6]]
    if rownr is None:
        row_chosen = int(arr.shape[0]/1.3)
    else:
        row_chosen = rownr
    ae_tracked_chosen = np.rad2deg(1e-6*ae_tracked[row_chosen,:])
    ae_cmd_chosen = ae_cmd_all[row_chosen,:]

    return ae_tracked_chosen, ae_cmd_chosen 


if __name__ == '__main__':
    import scipy as sp

    path = r'analyses/on_orbit_calibration/MO_res_for_cust'
    fname_log1 = 'Moon_29-01-2024_230229_PM.csv'

    arr = np.genfromtxt(f'{path}/{fname_log1}', delimiter=';', skip_header=4)

    ii_start_man = np.where(arr[:,-2] == 1)[0][0]
    
    t_vec_all_from0 = arr[:,1] + arr[:,2]*1e-3 - arr[0,1]
    t_vec_used = t_vec_all_from0[:ii_start_man]
    ae_moon = arr[:ii_start_man,[3,4]]

    tstart_man = t_vec_all_from0[ii_start_man:]
    t_vec_man = [tstart_man[0] + ii*0.05 for ii, t in enumerate(tstart_man)]
    tstart_man = tstart_man[0]

    az_moon_exrapoator = sp.interpolate.interp1d(t_vec_used, ae_moon[:,0],  fill_value = 'extrapolate', kind = 'linear')
    el_moon_exrapoator = sp.interpolate.interp1d(t_vec_used, ae_moon[:,1],  fill_value = 'extrapolate', kind = 'linear')

    ae_at_tman = [
    float(az_moon_exrapoator(tstart_man)),
    float(el_moon_exrapoator(tstart_man))
    ]

# %%
ae_at_tman
# Out:
# [-1.6806295988237376, 0.31628630709130523]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os 
import datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import importlib
import os, sys
sys.path.insert(1, os.getcwd()[:os.getcwd().index('astropynaric')+13])
## MVP imports
import basic_tools.vector_operations as vec_calc
import astronomy_tools.constants as const
import astronomy_tools.astro_targets as where_sun
import plotting_tools.basic_plotting as bplt
import basic_tools.time_conversion as t_conv
import basic_tools.in_out as out
import attitude_tools.conversions as conv
import analyses.on_orbit_calibration.MO_res_for_cust.resolve_Qmo as Q_mo_fix
importlib.reload(conv)

# read log
def get_cmd_from_log(logname, rownr = None, arr = None):
    if arr is None:
        arr = np.genfromtxt(logname, delimiter = ';', skip_header=3)

    ae_cmd_all = arr[:,[3,4]]
    ae_tracked = arr[:,[5,6]]
    if rownr is None:
        row_chosen = int(arr.shape[0]/1.3)
    else:
        row_chosen = rownr
    ae_tracked_chosen = np.rad2deg(1e-6*ae_tracked[row_chosen,:])
    ae_cmd_chosen = ae_cmd_all[row_chosen,:]

    return ae_tracked_chosen, ae_cmd_chosen 


if __name__ == '__main__':
    import scipy as sp

    path = r'analyses/on_orbit_calibration/MO_res_for_cust'
    fname_log1 = 'Moon_29-01-2024_230229_PM.csv'

    arr = np.genfromtxt(f'{path}/{fname_log1}', delimiter=';', skip_header=4)

    ii_start_man = np.where(arr[:,-2] == 1)[0][0]
    
    t_vec_all_from0 = arr[:,1] + arr[:,2]*1e-3 - arr[0,1]
    t_vec_used = t_vec_all_from0[:ii_start_man]
    ae_moon = arr[:ii_start_man,[3,4]]

    tstart_man = t_vec_all_from0[ii_start_man:]
    t_vec_man = [tstart_man[0] + ii*0.05 for ii, t in enumerate(tstart_man)]
    tstart_man = tstart_man[0]

    az_moon_exrapoator = sp.interpolate.interp1d(t_vec_used, ae_moon[:,0],  fill_value = 'extrapolate', kind = 'linear')
    el_moon_exrapoator = sp.interpolate.interp1d(t_vec_used, ae_moon[:,1],  fill_value = 'extrapolate', kind = 'linear')

    ae_at_tman = [
    float(az_moon_exrapoator(tstart_man)),
    float(el_moon_exrapoator(tstart_man))
    ]

#  113.67999992370605,
#  113.72999992370606,
#  113.77999992370606,
#  113.82999992370605,
#  113.87999992370607,
#  113.92999992370605,
#  113.97999992370606,
#  114.02999992370606,
#  114.07999992370605,
#  114.12999992370607,
#  114.17999992370605,
#  114.22999992370606,
#  114.27999992370606,
#  114.32999992370605,
#  114.37999992370607,
#  114.42999992370605,
#  114.47999992370606,
#  114.52999992370606,
#  114.57999992370605,
#  114.62999992370607,
#  114.67999992370605,
#  114.72999992370606,
#  114.77999992370606,
#  114.82999992370605,
#  114.87999992370607,
#  114.92999992370605,
#  114.97999992370606,
#  115.02999992370606,
#  115.07999992370605,
#  115.12999992370607,
#  115.17999992370605,
#  115.22999992370606,
#  115.27999992370606,
#  115.32999992370605,
#  115.37999992370607,
#  115.42999992370605,
#  115.47999992370606,
#  115.52999992370606,
#  ...]

# %%
az_moon_exrapoator(100)
# Out:
# array(nan)

# %%
sp
# Out:
# <module 'scipy' from 'c:\\Users\\KPaliusis\\Anaconda3\\envs\\tudat-space\\lib\\site-packages\\scipy\\__init__.py'>

# %%
pip freeze
# Out:
# appdirs @ file:///home/conda/feedstock_root/build_artifacts/appdirs_1603108395799/workNote: you may need to restart the kernel to use updated packages.
#
# apptools==5.2.0
# astropy==5.2.2
# asttokens @ file:///home/conda/feedstock_root/build_artifacts/asttokens_1670263926556/work
# attrs==23.1.0
# backcall @ file:///home/conda/feedstock_root/build_artifacts/backcall_1592338393461/work
# backports.functools-lru-cache @ file:///home/conda/feedstock_root/build_artifacts/backports.functools_lru_cache_1618230623929/work
# brotlipy @ file:///D:/bld/brotlipy_1666764804378/work
# certifi==2022.12.7
# cffi @ file:///D:/bld/cffi_1671179506518/work
# charset-normalizer @ file:///home/conda/feedstock_root/build_artifacts/charset-normalizer_1661170624537/work
# click==8.1.7
# click-plugins==1.1.1
# cligj==0.7.2
# colorama @ file:///home/conda/feedstock_root/build_artifacts/colorama_1666700638685/work
# comm @ file:///home/conda/feedstock_root/build_artifacts/comm_1670575068857/work
# configobj==5.0.8
# contourpy @ file:///D:/bld/contourpy_1673633923174/work
# cryptography @ file:///D:/bld/cryptography-split_1675828851033/work
# cycler @ file:///home/conda/feedstock_root/build_artifacts/cycler_1635519461629/work
# debugpy @ file:///D:/bld/debugpy_1674522535951/work
# decorator @ file:///home/conda/feedstock_root/build_artifacts/decorator_1641555617451/work
# envisage==6.1.1
# executing @ file:///home/conda/feedstock_root/build_artifacts/executing_1667317341051/work
# fastjsonschema==2.18.1
# Fiona==1.9.4.post1
# fonttools @ file:///D:/bld/fonttools_1666827169023/work
# geopandas==0.14.0
# idna @ file:///home/conda/feedstock_root/build_artifacts/idna_1663625384323/work
# importlib-metadata @ file:///home/conda/feedstock_root/build_artifacts/importlib-metadata_1672612343532/work
# ipykernel @ file:///D:/bld/ipykernel_1676322367019/work
# ipython @ file:///D:/bld/ipython_1676047671725/work
# jedi @ file:///home/conda/feedstock_root/build_artifacts/jedi_1669134318875/work
# jplephem==2.18
# jsonschema==4.19.1
# jsonschema-specifications==2023.7.1
# jupyter_client @ file:///home/conda/feedstock_root/build_artifacts/jupyter_client_1676579893731/work
# jupyter_core @ file:///D:/bld/jupyter_core_1675110116927/work
# kiwisolver @ file:///D:/bld/kiwisolver_1666805768319/work
# matplotlib @ file:///D:/bld/matplotlib-suite_1676406667384/work
# matplotlib-inline @ file:///home/conda/feedstock_root/build_artifacts/matplotlib-inline_1660814786464/work
# mayavi==4.8.1
# munkres==1.1.4
# mycolorpy==1.5.1
# nbformat==5.9.2
# nest-asyncio @ file:///home/conda/feedstock_root/build_artifacts/nest-asyncio_1664684991461/work
# numpy @ file:///D:/bld/numpy_1675642725500/work
# packaging @ file:///home/conda/feedstock_root/build_artifacts/packaging_1673482170163/work
# pandas @ file:///D:/bld/pandas_1674136614909/work
# parso @ file:///home/conda/feedstock_root/build_artifacts/parso_1638334955874/work
# pickleshare @ file:///home/conda/feedstock_root/build_artifacts/pickleshare_1602536217715/work
# Pillow @ file:///D:/bld/pillow_1675487397478/work
# platformdirs @ file:///home/conda/feedstock_root/build_artifacts/platformdirs_1675735718929/work
# plotly==5.17.0
# ply==3.11
# pooch @ file:///home/conda/feedstock_root/build_artifacts/pooch_1643032624649/work
# prompt-toolkit @ file:///home/conda/feedstock_root/build_artifacts/prompt-toolkit_1670414775770/work
# psutil @ file:///D:/bld/psutil_1667886056621/work
# pure-eval @ file:///home/conda/feedstock_root/build_artifacts/pure_eval_1642875951954/work
# pybind11 @ file:///D:/bld/pybind11-split_1672786438967/work
# pybind11-global @ file:///D:/bld/pybind11-split_1672786438967/work
# pycparser @ file:///home/conda/feedstock_root/build_artifacts/pycparser_1636257122734/work
# pyerfa==2.0.0.3
# pyface==7.4.4
# Pygments @ file:///home/conda/feedstock_root/build_artifacts/pygments_1672682006896/work
# pyOpenSSL @ file:///home/conda/feedstock_root/build_artifacts/pyopenssl_1672659226110/work
# pyparsing @ file:///home/conda/feedstock_root/build_artifacts/pyparsing_1652235407899/work
# pyproj==3.6.1
# PyQt5==5.15.7
# PyQt5-sip @ file:///D:/bld/pyqt-split_1674666795342/work/pyqt_sip
# PySocks @ file:///D:/bld/pysocks_1661604991356/work
# python-dateutil @ file:///home/conda/feedstock_root/build_artifacts/python-dateutil_1626286286081/work
# pytz @ file:///home/conda/feedstock_root/build_artifacts/pytz_1673864280276/work
# pywin32==304
# PyYAML==6.0
# pyzmq @ file:///D:/bld/pyzmq_1673612813207/work
# referencing==0.30.2
# requests @ file:///home/conda/feedstock_root/build_artifacts/requests_1673863902341/work
# rpds-py==0.10.3
# scipy==1.10.1
# sgp4==2.21
# shapely==2.0.1
# sip @ file:///D:/bld/sip_1675696789560/work
# six @ file:///home/conda/feedstock_root/build_artifacts/six_1620240208055/work
# skyfield==1.46
# stack-data @ file:///home/conda/feedstock_root/build_artifacts/stack_data_1669632077133/work
# tabulate @ file:///home/conda/feedstock_root/build_artifacts/tabulate_1665138452165/work
# tenacity==8.2.3
# toml @ file:///home/conda/feedstock_root/build_artifacts/toml_1604308577558/work
# tornado @ file:///D:/bld/tornado_1666788744359/work
# traitlets @ file:///home/conda/feedstock_root/build_artifacts/traitlets_1675110562325/work
# traits==6.4.1
# traitsui==7.4.3
# typing_extensions @ file:///home/conda/feedstock_root/build_artifacts/typing_extensions_1665144421445/work
# unicodedata2 @ file:///D:/bld/unicodedata2_1667239969015/work
# urllib3 @ file:///home/conda/feedstock_root/build_artifacts/urllib3_1673452138552/work
# vtk==9.2.6
# wcwidth @ file:///home/conda/feedstock_root/build_artifacts/wcwidth_1673864653149/work
# win-inet-pton @ file:///D:/bld/win_inet_pton_1667051142467/work
# zipp @ file:///home/conda/feedstock_root/build_artifacts/zipp_1677313463193/work

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os 
import datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import importlib
import os, sys
sys.path.insert(1, os.getcwd()[:os.getcwd().index('astropynaric')+13])
## MVP imports
import basic_tools.vector_operations as vec_calc
import astronomy_tools.constants as const
import astronomy_tools.astro_targets as where_sun
import plotting_tools.basic_plotting as bplt
import basic_tools.time_conversion as t_conv
import basic_tools.in_out as out
import attitude_tools.conversions as conv
import analyses.on_orbit_calibration.MO_res_for_cust.resolve_Qmo as Q_mo_fix
importlib.reload(conv)

# read log
def get_cmd_from_log(logname, rownr = None, arr = None):
    if arr is None:
        arr = np.genfromtxt(logname, delimiter = ';', skip_header=3)

    ae_cmd_all = arr[:,[3,4]]
    ae_tracked = arr[:,[5,6]]
    if rownr is None:
        row_chosen = int(arr.shape[0]/1.3)
    else:
        row_chosen = rownr
    ae_tracked_chosen = np.rad2deg(1e-6*ae_tracked[row_chosen,:])
    ae_cmd_chosen = ae_cmd_all[row_chosen,:]

    return ae_tracked_chosen, ae_cmd_chosen 


if __name__ == '__main__':
    import scipy as sp

    path = r'analyses/on_orbit_calibration/MO_res_for_cust'
    fname_log1 = 'Moon_29-01-2024_230229_PM.csv'

    arr = np.genfromtxt(f'{path}/{fname_log1}', delimiter=';', skip_header=4)

    ii_start_man = np.where(arr[:,-2] == 1)[0][0]
    
    t_vec_all_from0 = arr[:,1] + arr[:,2]*1e-3 - arr[0,1]
    t_vec_used = t_vec_all_from0[:ii_start_man]
    ae_moon = arr[:ii_start_man,[3,4]]

    tstart_man = t_vec_all_from0[ii_start_man:]
    t_vec_man = [tstart_man[0] + ii*0.05 for ii, t in enumerate(tstart_man)]
    tstart_man = tstart_man[0]

    az_moon_exrapoator = sp.interpolate.CubicSpline(t_vec_used, ae_moon[:,0],  bc_type='not-a-knot')
    el_moon_exrapoator = sp.interpolate.CubicSpline(t_vec_used, ae_moon[:,1],  bc_type='not-a-knot')

    ae_at_tman = [
    float(az_moon_exrapoator(tstart_man)),
    float(el_moon_exrapoator(tstart_man))
    ]

    az_moon_cmd_from_man = az_moon_exrapoator(t_vec_man)
    el_moon_cmd_from_man = el_moon_exrapoator(t_vec_man)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\KPaliusis\Documents\Github_Repos\astropynaric\analyses\on_orbit_calibration\MO_res_for_cust\get_moon_deltas_for_square_raster.py:58
#      55 t_vec_man = [tstart_man[0] + ii*0.05 for ii, t in enumerate(tstart_man)]
#      56 tstart_man = tstart_man[0]
# ---> 58 az_moon_exrapoator = sp.interpolate.CubicSpline(t_vec_used, ae_moon[:,0],  bc_type='not-a-knot')
#      59 el_moon_exrapoator = sp.interpolate.CubicSpline(t_vec_used, ae_moon[:,1],  bc_type='not-a-knot')
#      61 ae_at_tman = [
#      62 float(az_moon_exrapoator(tstart_man)),
#      63 float(el_moon_exrapoator(tstart_man))
#      64 ]
#
# File c:\Users\KPaliusis\Anaconda3\envs\tudat-space\lib\site-packages\scipy\interpolate\_cubic.py:635, in CubicSpline.__init__(self, x, y, axis, bc_type, extrapolate)
#     634 def __init__(self, x, y, axis=0, bc_type='not-a-knot', extrapolate=None):
# --> 635     x, dx, y, axis, _ = prepare_input(x, y, axis)
#     636     n = len(x)
#     638     bc, y = self._validate_bc(bc_type, y, y.shape[1:], axis)
#
# File c:\Users\KPaliusis\Anaconda3\envs\tudat-space\lib\site-packages\scipy\interpolate\_cubic.py:61, in prepare_input(x, y, axis, dydx)
#      59 dx = np.diff(x)
#      60 if np.any(dx <= 0):
# ---> 61     raise ValueError("`x` must be strictly increasing sequence.")
#      63 y = np.moveaxis(y, axis, 0)
#      64 if dydx is not None:
#
# ValueError: `x` must be strictly increasing sequence.

# %%
t_vec_used
# Out:
# array([ 0.74699998,  0.77200007,  0.79699993, ..., 65.55500007,
#        65.57999992, 65.57999992])

# %%
np.gradient(t_vec_used)
# Out:
# array([0.0250001 , 0.02499998, 0.02499998, ..., 0.02549994, 0.01249993,
#        0.        ])

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os 
import datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import importlib
import os, sys
sys.path.insert(1, os.getcwd()[:os.getcwd().index('astropynaric')+13])
## MVP imports
import basic_tools.vector_operations as vec_calc
import astronomy_tools.constants as const
import astronomy_tools.astro_targets as where_sun
import plotting_tools.basic_plotting as bplt
import basic_tools.time_conversion as t_conv
import basic_tools.in_out as out
import attitude_tools.conversions as conv
import analyses.on_orbit_calibration.MO_res_for_cust.resolve_Qmo as Q_mo_fix
importlib.reload(conv)

# read log
def get_cmd_from_log(logname, rownr = None, arr = None):
    if arr is None:
        arr = np.genfromtxt(logname, delimiter = ';', skip_header=3)

    ae_cmd_all = arr[:,[3,4]]
    ae_tracked = arr[:,[5,6]]
    if rownr is None:
        row_chosen = int(arr.shape[0]/1.3)
    else:
        row_chosen = rownr
    ae_tracked_chosen = np.rad2deg(1e-6*ae_tracked[row_chosen,:])
    ae_cmd_chosen = ae_cmd_all[row_chosen,:]

    return ae_tracked_chosen, ae_cmd_chosen 


if __name__ == '__main__':
    import scipy as sp

    path = r'analyses/on_orbit_calibration/MO_res_for_cust'
    fname_log1 = 'Moon_29-01-2024_230229_PM.csv'

    arr = np.genfromtxt(f'{path}/{fname_log1}', delimiter=';', skip_header=4)

    ii_start_man = np.where(arr[:,-2] == 1)[0][0]
    
    t_vec_all_from0 = arr[:,1] + arr[:,2]*1e-3
    t_vec_all_from0 = t_vec_all_from0 - t_vec_all_from0[0]
    t_vec_used = t_vec_all_from0[:ii_start_man]
    ae_moon = arr[:ii_start_man,[3,4]]

    tstart_man = t_vec_all_from0[ii_start_man:]
    t_vec_man = [tstart_man[0] + ii*0.05 for ii, t in enumerate(tstart_man)]
    tstart_man = tstart_man[0]

    az_moon_exrapoator = sp.interpolate.CubicSpline(t_vec_used, ae_moon[:,0],  bc_type='not-a-knot')
    el_moon_exrapoator = sp.interpolate.CubicSpline(t_vec_used, ae_moon[:,1],  bc_type='not-a-knot')

    ae_at_tman = [
    float(az_moon_exrapoator(tstart_man)),
    float(el_moon_exrapoator(tstart_man))
    ]

    az_moon_cmd_from_man = az_moon_exrapoator(t_vec_man)
    el_moon_cmd_from_man = el_moon_exrapoator(t_vec_man)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\KPaliusis\Documents\Github_Repos\astropynaric\analyses\on_orbit_calibration\MO_res_for_cust\get_moon_deltas_for_square_raster.py:59
#      56 t_vec_man = [tstart_man[0] + ii*0.05 for ii, t in enumerate(tstart_man)]
#      57 tstart_man = tstart_man[0]
# ---> 59 az_moon_exrapoator = sp.interpolate.CubicSpline(t_vec_used, ae_moon[:,0],  bc_type='not-a-knot')
#      60 el_moon_exrapoator = sp.interpolate.CubicSpline(t_vec_used, ae_moon[:,1],  bc_type='not-a-knot')
#      62 ae_at_tman = [
#      63 float(az_moon_exrapoator(tstart_man)),
#      64 float(el_moon_exrapoator(tstart_man))
#      65 ]
#
# File c:\Users\KPaliusis\Anaconda3\envs\tudat-space\lib\site-packages\scipy\interpolate\_cubic.py:635, in CubicSpline.__init__(self, x, y, axis, bc_type, extrapolate)
#     634 def __init__(self, x, y, axis=0, bc_type='not-a-knot', extrapolate=None):
# --> 635     x, dx, y, axis, _ = prepare_input(x, y, axis)
#     636     n = len(x)
#     638     bc, y = self._validate_bc(bc_type, y, y.shape[1:], axis)
#
# File c:\Users\KPaliusis\Anaconda3\envs\tudat-space\lib\site-packages\scipy\interpolate\_cubic.py:61, in prepare_input(x, y, axis, dydx)
#      59 dx = np.diff(x)
#      60 if np.any(dx <= 0):
# ---> 61     raise ValueError("`x` must be strictly increasing sequence.")
#      63 y = np.moveaxis(y, axis, 0)
#      64 if dydx is not None:
#
# ValueError: `x` must be strictly increasing sequence.

# %%
np.gradient(t_vec_used)
# Out:
# array([0.0250001 , 0.02499998, 0.02499998, ..., 0.02549994, 0.01249993,
#        0.        ])

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os 
import datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import importlib
import os, sys
sys.path.insert(1, os.getcwd()[:os.getcwd().index('astropynaric')+13])
## MVP imports
import basic_tools.vector_operations as vec_calc
import astronomy_tools.constants as const
import astronomy_tools.astro_targets as where_sun
import plotting_tools.basic_plotting as bplt
import basic_tools.time_conversion as t_conv
import basic_tools.in_out as out
import attitude_tools.conversions as conv
import analyses.on_orbit_calibration.MO_res_for_cust.resolve_Qmo as Q_mo_fix
importlib.reload(conv)

# read log
def get_cmd_from_log(logname, rownr = None, arr = None):
    if arr is None:
        arr = np.genfromtxt(logname, delimiter = ';', skip_header=3)

    ae_cmd_all = arr[:,[3,4]]
    ae_tracked = arr[:,[5,6]]
    if rownr is None:
        row_chosen = int(arr.shape[0]/1.3)
    else:
        row_chosen = rownr
    ae_tracked_chosen = np.rad2deg(1e-6*ae_tracked[row_chosen,:])
    ae_cmd_chosen = ae_cmd_all[row_chosen,:]

    return ae_tracked_chosen, ae_cmd_chosen 


if __name__ == '__main__':
    import scipy as sp

    path = r'analyses/on_orbit_calibration/MO_res_for_cust'
    fname_log1 = 'Moon_29-01-2024_230229_PM.csv'

    arr = np.genfromtxt(f'{path}/{fname_log1}', delimiter=';', skip_header=4)

    ii_start_man = np.where(arr[:,-2] == 1)[0][0]-1
    
    t_vec_all_from0 = arr[:,1] + arr[:,2]*1e-3
    t_vec_all_from0 = t_vec_all_from0 - t_vec_all_from0[0]
    t_vec_used = t_vec_all_from0[:ii_start_man]
    ae_moon = arr[:ii_start_man,[3,4]]

    tstart_man = t_vec_all_from0[ii_start_man:]
    t_vec_man = [tstart_man[0] + ii*0.05 for ii, t in enumerate(tstart_man)]
    tstart_man = tstart_man[0]

    az_moon_exrapoator = sp.interpolate.CubicSpline(t_vec_used, ae_moon[:,0],  bc_type='not-a-knot')
    el_moon_exrapoator = sp.interpolate.CubicSpline(t_vec_used, ae_moon[:,1],  bc_type='not-a-knot')

    ae_at_tman = [
    float(az_moon_exrapoator(tstart_man)),
    float(el_moon_exrapoator(tstart_man))
    ]

    az_moon_cmd_from_man = az_moon_exrapoator(t_vec_man)
    el_moon_cmd_from_man = el_moon_exrapoator(t_vec_man)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\KPaliusis\Documents\Github_Repos\astropynaric\analyses\on_orbit_calibration\MO_res_for_cust\get_moon_deltas_for_square_raster.py:59
#      56 t_vec_man = [tstart_man[0] + ii*0.05 for ii, t in enumerate(tstart_man)]
#      57 tstart_man = tstart_man[0]
# ---> 59 az_moon_exrapoator = sp.interpolate.CubicSpline(t_vec_used, ae_moon[:,0],  bc_type='not-a-knot')
#      60 el_moon_exrapoator = sp.interpolate.CubicSpline(t_vec_used, ae_moon[:,1],  bc_type='not-a-knot')
#      62 ae_at_tman = [
#      63 float(az_moon_exrapoator(tstart_man)),
#      64 float(el_moon_exrapoator(tstart_man))
#      65 ]
#
# File c:\Users\KPaliusis\Anaconda3\envs\tudat-space\lib\site-packages\scipy\interpolate\_cubic.py:635, in CubicSpline.__init__(self, x, y, axis, bc_type, extrapolate)
#     634 def __init__(self, x, y, axis=0, bc_type='not-a-knot', extrapolate=None):
# --> 635     x, dx, y, axis, _ = prepare_input(x, y, axis)
#     636     n = len(x)
#     638     bc, y = self._validate_bc(bc_type, y, y.shape[1:], axis)
#
# File c:\Users\KPaliusis\Anaconda3\envs\tudat-space\lib\site-packages\scipy\interpolate\_cubic.py:61, in prepare_input(x, y, axis, dydx)
#      59 dx = np.diff(x)
#      60 if np.any(dx <= 0):
# ---> 61     raise ValueError("`x` must be strictly increasing sequence.")
#      63 y = np.moveaxis(y, axis, 0)
#      64 if dydx is not None:
#
# ValueError: `x` must be strictly increasing sequence.

# %%
np.gradient(t_vec_used)
# Out:
# array([0.0250001 , 0.02499998, 0.02499998, ..., 0.02550006, 0.02549994,
#        0.02499986])

# %%
np.min(t_vec_used|)
# Out:
#   Cell In[28], line 1
#     np.min(t_vec_used|)
#                       ^
# SyntaxError: invalid syntax

# %%
np.min(t_vec_used)
# Out:
# 0.0

# %%
np.where(t_vec_used == 0.0)
# Out:
# (array([0], dtype=int64),)

# %%
np.min(np.gradient(t_vec_used))
# Out:
# -18.439000010490417

# %%
plt.plot(t_vec_used)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os 
import datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import importlib
import os, sys
sys.path.insert(1, os.getcwd()[:os.getcwd().index('astropynaric')+13])
## MVP imports
import basic_tools.vector_operations as vec_calc
import astronomy_tools.constants as const
import astronomy_tools.astro_targets as where_sun
import plotting_tools.basic_plotting as bplt
import basic_tools.time_conversion as t_conv
import basic_tools.in_out as out
import attitude_tools.conversions as conv
import analyses.on_orbit_calibration.MO_res_for_cust.resolve_Qmo as Q_mo_fix
importlib.reload(conv)

# read log
def get_cmd_from_log(logname, rownr = None, arr = None):
    if arr is None:
        arr = np.genfromtxt(logname, delimiter = ';', skip_header=3)

    ae_cmd_all = arr[:,[3,4]]
    ae_tracked = arr[:,[5,6]]
    if rownr is None:
        row_chosen = int(arr.shape[0]/1.3)
    else:
        row_chosen = rownr
    ae_tracked_chosen = np.rad2deg(1e-6*ae_tracked[row_chosen,:])
    ae_cmd_chosen = ae_cmd_all[row_chosen,:]

    return ae_tracked_chosen, ae_cmd_chosen 


if __name__ == '__main__':
    import scipy as sp

    path = r'analyses/on_orbit_calibration/MO_res_for_cust'
    fname_log1 = 'Moon_29-01-2024_230229_PM.csv'

    arr = np.genfromtxt(f'{path}/{fname_log1}', delimiter=';', skip_header=4)

    ii_start_man = np.where(arr[:,-2] == 1)[0][0]-1
    
    t_vec_all_from0 = arr[:,1] + arr[:,2]*1e-3
    t_vec_all_from0 = t_vec_all_from0 - t_vec_all_from0[0]
    t_vec_used = t_vec_all_from0[:ii_start_man]
    t_vec_used = [t for ii,t in enumerate(t_vec_used) if t_vec_used[ii] < t_vec_used[ii+1]]
    ae_moon = arr[:ii_start_man,[3,4]]

    tstart_man = t_vec_all_from0[ii_start_man:]
    t_vec_man = [tstart_man[0] + ii*0.05 for ii, t in enumerate(tstart_man)]
    tstart_man = tstart_man[0]

    az_moon_exrapoator = sp.interpolate.CubicSpline(t_vec_used, ae_moon[:,0],  bc_type='not-a-knot')
    el_moon_exrapoator = sp.interpolate.CubicSpline(t_vec_used, ae_moon[:,1],  bc_type='not-a-knot')

    ae_at_tman = [
    float(az_moon_exrapoator(tstart_man)),
    float(el_moon_exrapoator(tstart_man))
    ]

    az_moon_cmd_from_man = az_moon_exrapoator(t_vec_man)
    el_moon_cmd_from_man = el_moon_exrapoator(t_vec_man)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File c:\Users\KPaliusis\Documents\Github_Repos\astropynaric\analyses\on_orbit_calibration\MO_res_for_cust\get_moon_deltas_for_square_raster.py:53
#      51 t_vec_all_from0 = t_vec_all_from0 - t_vec_all_from0[0]
#      52 t_vec_used = t_vec_all_from0[:ii_start_man]
# ---> 53 t_vec_used = [t for ii,t in enumerate(t_vec_used) if t_vec_used[ii] < t_vec_used[ii+1]]
#      54 ae_moon = arr[:ii_start_man,[3,4]]
#      56 tstart_man = t_vec_all_from0[ii_start_man:]
#
# File c:\Users\KPaliusis\Documents\Github_Repos\astropynaric\analyses\on_orbit_calibration\MO_res_for_cust\get_moon_deltas_for_square_raster.py:53
#      51 t_vec_all_from0 = t_vec_all_from0 - t_vec_all_from0[0]
#      52 t_vec_used = t_vec_all_from0[:ii_start_man]
# ---> 53 t_vec_used = [t for ii,t in enumerate(t_vec_used) if t_vec_used[ii] < t_vec_used[ii+1]]
#      54 ae_moon = arr[:ii_start_man,[3,4]]
#      56 tstart_man = t_vec_all_from0[ii_start_man:]
#
# IndexError: index 2576 is out of bounds for axis 0 with size 2576

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os 
import datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import importlib
import os, sys
sys.path.insert(1, os.getcwd()[:os.getcwd().index('astropynaric')+13])
## MVP imports
import basic_tools.vector_operations as vec_calc
import astronomy_tools.constants as const
import astronomy_tools.astro_targets as where_sun
import plotting_tools.basic_plotting as bplt
import basic_tools.time_conversion as t_conv
import basic_tools.in_out as out
import attitude_tools.conversions as conv
import analyses.on_orbit_calibration.MO_res_for_cust.resolve_Qmo as Q_mo_fix
importlib.reload(conv)

# read log
def get_cmd_from_log(logname, rownr = None, arr = None):
    if arr is None:
        arr = np.genfromtxt(logname, delimiter = ';', skip_header=3)

    ae_cmd_all = arr[:,[3,4]]
    ae_tracked = arr[:,[5,6]]
    if rownr is None:
        row_chosen = int(arr.shape[0]/1.3)
    else:
        row_chosen = rownr
    ae_tracked_chosen = np.rad2deg(1e-6*ae_tracked[row_chosen,:])
    ae_cmd_chosen = ae_cmd_all[row_chosen,:]

    return ae_tracked_chosen, ae_cmd_chosen 


if __name__ == '__main__':
    import scipy as sp

    path = r'analyses/on_orbit_calibration/MO_res_for_cust'
    fname_log1 = 'Moon_29-01-2024_230229_PM.csv'

    arr = np.genfromtxt(f'{path}/{fname_log1}', delimiter=';', skip_header=4)

    ii_start_man = np.where(arr[:,-2] == 1)[0][0]-1
    
    t_vec_all_from0 = arr[:,1] + arr[:,2]*1e-3
    t_vec_all_from0 = t_vec_all_from0 - t_vec_all_from0[0]
    t_vec_used = t_vec_all_from0[:ii_start_man]
    for ii, t in enumerate(t_vec_used[:-1]):
        if t > t_vec_used[ii+1]:
            t_vec_used[ii+1] = t + 0.025
    ae_moon = arr[:ii_start_man,[3,4]]

    tstart_man = t_vec_all_from0[ii_start_man:]
    t_vec_man = [tstart_man[0] + ii*0.05 for ii, t in enumerate(tstart_man)]
    tstart_man = tstart_man[0]

    az_moon_exrapoator = sp.interpolate.CubicSpline(t_vec_used, ae_moon[:,0],  bc_type='not-a-knot')
    el_moon_exrapoator = sp.interpolate.CubicSpline(t_vec_used, ae_moon[:,1],  bc_type='not-a-knot')

    ae_at_tman = [
    float(az_moon_exrapoator(tstart_man)),
    float(el_moon_exrapoator(tstart_man))
    ]

    az_moon_cmd_from_man = az_moon_exrapoator(t_vec_man)
    el_moon_cmd_from_man = el_moon_exrapoator(t_vec_man)
